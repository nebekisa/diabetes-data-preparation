# %%
# Phase 4: Data Reduction
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../src')

from data_reduction import execute_data_reduction_pipeline

print("🚀 STARTING PHASE 4: DATA REDUCTION")
print("=" * 50)

# Load the transformed data from Phase 3
df_transformed = pd.read_csv('../data/processed/diabetes_transformed.csv')
print(f"Loaded transformed data: {df_transformed.shape}")

# Display feature overview
print(f"\n📊 DATASET OVERVIEW:")
print(f"• Total features: {df_transformed.shape[1]}")
print(f"• Samples: {df_transformed.shape[0]}")

feature_categories = {
    'Original Numerical': [col for col in df_transformed.columns if col in 
                          ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 
                           'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']],
    'Scaled Features': [col for col in df_transformed.columns if '_Scaled' in col],
    'Clinical Categories': [col for col in df_transformed.columns if 'Category' in col or 'Group' in col],
    'Interaction Features': [col for col in df_transformed.columns if 'Interaction' in col or 'Score' in col],
    'Encoded Features': [col for col in df_transformed.columns if 'Encoded' in col]
}

for category, features in feature_categories.items():
    print(f"• {category}: {len(features)} features")

# Execute reduction pipeline
reduced_df, selected_features, reduction_report = execute_data_reduction_pipeline(
    df_transformed, 
    target_col='Outcome',
    n_final_features=15
)

# Save reduced dataset
reduced_df.to_csv('../data/processed/diabetes_reduced.csv', index=False)
print(f"\n💾 Reduced data saved to: ../data/processed/diabetes_reduced.csv")
print(f"📉 Final dataset: {reduced_df.shape}")

# Save feature selection report
import json
feature_report = {
    'selected_features': selected_features,
    'feature_count_original': df_transformed.shape[1],
    'feature_count_reduced': reduced_df.shape[1],
    'reduction_percentage': f"{((df_transformed.shape[1] - reduced_df.shape[1]) / df_transformed.shape[1]) * 100:.1f}%"
}

with open('../data/processed/feature_selection_report.json', 'w') as f:
    json.dump(feature_report, f, indent=2)

print(f"\n📋 Feature selection report saved")

# Final comparison
print("\n🎯 PHASE 4 COMPLETION SUMMARY")
print("=" * 40)
print(f"Original features: {df_transformed.shape[1]}")
print(f"Selected features: {len(selected_features)}")
print(f"Reduction: {feature_report['reduction_percentage']}")
print(f"Final dataset shape: {reduced_df.shape}")

print("\n✅ PHASE 4: DATA REDUCTION COMPLETE!")
# Out:
# 🚀 STARTING PHASE 4: DATA REDUCTION
# ==================================================
# Loaded transformed data: (768, 32)
#
# 📊 DATASET OVERVIEW:
# • Total features: 32
# • Samples: 768
# • Original Numerical: 9 features
# • Scaled Features: 8 features
# • Clinical Categories: 12 features
# • Interaction Features: 3 features
# • Encoded Features: 3 features
# 🔗 COMPREHENSIVE FEATURE CORRELATION ANALYSIS
# ==================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 37
#      34     print(f"• {category}: {len(features)} features")
#      36 # Execute reduction pipeline
# ---> 37 reduced_df, selected_features, reduction_report = execute_data_reduction_pipeline(
#      38     df_transformed,
#      39     target_col='Outcome',
#      40     n_final_features=15
#      41 )
#      43 # Save reduced dataset
#      44 reduced_df.to_csv('../data/processed/diabetes_reduced.csv', index=False)
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\notebooks\../src\data_reduction.py:409, in execute_data_reduction_pipeline(df, target_col, n_final_features)
#     406 reducer = DiabetesDataReducer(df, target_col)
#     408 # Step 1: Correlation analysis
# --> 409 reducer.analyze_feature_correlations()
#     411 # Step 2: Multiple feature selection methods
#     412 reducer.mutual_information_analysis()
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\notebooks\../src\data_reduction.py:43, in DiabetesDataReducer.analyze_feature_correlations(self)
#      40 print("=" * 50)
#      42 # Calculate correlation matrix
# ---> 43 corr_matrix = self.X.corr()
#      45 # Find highly correlated features (absolute correlation > 0.8)
#      46 high_corr_pairs = []
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\.venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\.venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\.venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\hp\Desktop\diabetes-data-preparation\.venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: '50-59'
